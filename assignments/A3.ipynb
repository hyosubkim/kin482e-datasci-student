# %% [markdown]
# Make sure you fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. After you've typed in your answer delete (or comment out) the line that says ```raise NotImplementedError()```.
#
# **Before you turn this assignment in, make sure everything runs as expected. From the menubar, select Kernel $\rightarrow$ Restart Kernel and Run All Cells.**

# %%
# Write your name and the names of anyone you worked with
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # Assignment 3: Making functions

# %% [markdown]
# ### Simulating a dynamical system
#
# In mathematics, a [dynamical system](https://en.wikipedia.org/wiki/Dynamical_system) is a system
# in which a function describes the time dependence of a point in a geometrical space. A canonical
# example of a dynamical system is the [logistic map](https://en.wikipedia.org/wiki/Logistic_map),
# a growth model that computes a new population density (between  0 and 1) based on the current
# density. In the model, time takes discrete values 0, 1, 2, ...

# %% [markdown]
# ## Part 1 (1 pt):
# Define a function called `logistic_map` that takes two inputs: `x`, representing the current
# population (at time `t`), and a parameter `r`, which we will set to 1 for now (i.e., `r=1`). This function should return a value representing the state of the system (population) at the next time step `t + 1`, as described by the following equation:
#
# $$x_{t+1} = r x{_t} (1 - x_{t})$$
#
# Note that the indexing is not necessary within the function itself, as you will be using a loop in a later step(s). Make sure you define the function with the name `logistic_map`.

# %%
# Your answer here (Part 1)
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ---
# ## Part 2 (2 pts):
# Starting from an initial population of 0.5, which represents the population at time `t = 0`, use a `for` loop to iterate the `logistic_map` function you just defined for 10 additional time steps. Store the intermediate results in a list so that after the loop terminates you have accumulated a sequence of values representing the state of the logistic map at times `t = [0, 1,..., t_final]` (**thus, 11 values in total**). Assign these values into a list called `population_series`.

# %%
# Your answer here (Part 2)
population_series = []
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ---
# ## Part 3 (2 pts):
# Encapsulate the logic of your loop into a function called `iterate` that takes the parameter `initial_population` as its first input, the parameter `t_final` as its second input, and the parameter `r` as its third input. The function should return the list of values representing the state of the logistic map at times `t = [0,1,...,t_final]`.  **Make sure your function is defined as `iterate`.**
#
# **Graded portion:** Test your `iterate` function with an `initial_population = 1` and `t_final = 100` and `t_final = 1000`. Store the outputs into variables `population_series_1` and `population_series_2`. Don't forget to include the population at `t = 0` as well.
#
#
#
# **For your own insight into the model:** Run this function for periods `t_final = 100`
# and `1000` and print some of the values. Try it with different initial populations and different values of `r`. Is the population trending toward a steady state?

# %%
# Your answer here (Part 3)
# YOUR CODE HERE
raise NotImplementedError()
